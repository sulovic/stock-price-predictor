# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import os


# Load data
X_train = pd.read_csv(
    '../data/prepared/X_train_scaled.csv').drop("Date", axis=1).values
y_train = pd.read_csv(
    '../data/prepared/y_train_scaled.csv').drop("Date", axis=1).values
X_test = pd.read_csv(
    '../data/prepared/X_test_scaled.csv').drop("Date", axis=1).values
y_test = pd.read_csv(
    '../data/prepared/y_test_scaled.csv').drop("Date", axis=1).values

# Replace 0s y with NaN
y_train[y_train == 0] = np.nan
y_test[y_test == 0] = np.nan



# Define a custom masked MSE loss function for stocks with non trading days

def masked_mse(y_true, y_pred):
    mask = ~tf.math.is_nan(y_true)
    y_true = tf.where(mask, y_true, 0.0)
    y_pred = tf.where(mask, y_pred, 0.0)
    mse = tf.reduce_sum(tf.square(y_true - y_pred) * tf.cast(mask,
                        tf.float32)) / tf.reduce_sum(tf.cast(mask, tf.float32))
    return mse


# Define a simple Keras model

print(X_train.shape, y_train.shape)  # Get the shape of the input features


model = keras.Sequential([
    keras.Input(shape=(X_train.shape[1],)),  # Explicit Input layer
    keras.layers.Dense(128, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(32, activation='relu'),
    # Output layer with neurons equal to the number of stocks
    keras.layers.Dense(units=y_train.shape[1],)
])

model.compile(optimizer='adam', loss=masked_mse, metrics=[masked_mse])


# Train the model
model.fit(
    X_train,
    y_train,
    epochs=30,         # Number of times to go through the data
    batch_size=32,     # Number of samples per gradient update
    validation_data=(X_test, y_test)  # Optional: to monitor validation loss
)
# Evaluate the model
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}, Test MAE: {test_mae}')
# Make predictions
predictions = model.predict(X_test)
# Save the model
model.save('../models/stock_prediction_model.keras')
# Save predictions
predictions_df = pd.DataFrame(
    predictions, columns=['Stock1', 'Stock2', 'Stock3', 'Stock4'])

# Create folder if it doesn't exist
if not os.path.exists('../data/predictions'):
    os.makedirs('../data/predictions')

predictions_df.to_csv('../data/predictions/stock_predictions.csv', index=False)
# Save the model architecture
model_json = model.to_json()
# Out:
# (6428, 9) (6428, 4)
# E0000 00:00:1750087884.592090    4384 cuda_executor.cc:1228] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1750087884.594503    4384 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Epoch 1/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0471 - masked_mse: 0.0471 - val_loss: 0.0027 - val_masked_mse: 0.0034
# Epoch 2/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0027 - masked_mse: 0.0027 - val_loss: 0.0021 - val_masked_mse: 0.0027
# Epoch 3/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0023 - masked_mse: 0.0023 - val_loss: 0.0020 - val_masked_mse: 0.0028
# Epoch 4/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0021 - masked_mse: 0.0021 - val_loss: 0.0017 - val_masked_mse: 0.0023
# Epoch 5/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0019 - masked_mse: 0.0019 - val_loss: 0.0016 - val_masked_mse: 0.0021
# Epoch 6/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0019 - masked_mse: 0.0019 - val_loss: 0.0015 - val_masked_mse: 0.0019
# Epoch 7/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - masked_mse: 0.0017 - val_loss: 0.0013 - val_masked_mse: 0.0018
# Epoch 8/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0016 - masked_mse: 0.0016 - val_loss: 0.0013 - val_masked_mse: 0.0017
# Epoch 9/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0014 - masked_mse: 0.0014 - val_loss: 0.0011 - val_masked_mse: 0.0013
# Epoch 10/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0013 - masked_mse: 0.0013 - val_loss: 9.1838e-04 - val_masked_mse: 0.0011
# Epoch 11/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0012 - masked_mse: 0.0012 - val_loss: 8.1444e-04 - val_masked_mse: 9.0694e-04
# Epoch 12/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0010 - masked_mse: 0.0010 - val_loss: 7.9065e-04 - val_masked_mse: 9.1818e-04
# Epoch 13/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.4178e-04 - masked_mse: 9.4178e-04 - val_loss: 6.9293e-04 - val_masked_mse: 7.7199e-04
# Epoch 14/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.1133e-04 - masked_mse: 9.1133e-04 - val_loss: 7.9887e-04 - val_masked_mse: 8.6468e-04
# Epoch 15/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.0340e-04 - masked_mse: 9.0340e-04 - val_loss: 6.6458e-04 - val_masked_mse: 6.7643e-04
# Epoch 16/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.0790e-04 - masked_mse: 9.0790e-04 - val_loss: 7.1920e-04 - val_masked_mse: 7.8019e-04
# Epoch 17/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.5817e-04 - masked_mse: 8.5816e-04 - val_loss: 5.8209e-04 - val_masked_mse: 6.0855e-04
# Epoch 18/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.8897e-04 - masked_mse: 7.8897e-04 - val_loss: 7.4013e-04 - val_masked_mse: 7.4826e-04
# Epoch 19/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.9022e-04 - masked_mse: 8.9022e-04 - val_loss: 5.9628e-04 - val_masked_mse: 6.3040e-04
# Epoch 20/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.8632e-04 - masked_mse: 7.8632e-04 - val_loss: 7.1461e-04 - val_masked_mse: 7.1838e-04
# Epoch 21/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.0362e-04 - masked_mse: 8.0362e-04 - val_loss: 6.0493e-04 - val_masked_mse: 6.4082e-04
# Epoch 22/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.5371e-04 - masked_mse: 7.5371e-04 - val_loss: 5.8386e-04 - val_masked_mse: 6.1585e-04
# Epoch 23/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.7473e-04 - masked_mse: 7.7472e-04 - val_loss: 5.9114e-04 - val_masked_mse: 6.1472e-04
# Epoch 24/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5444e-04 - masked_mse: 7.5444e-04 - val_loss: 5.8339e-04 - val_masked_mse: 6.1999e-04
# Epoch 25/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.3482e-04 - masked_mse: 7.3483e-04 - val_loss: 5.2558e-04 - val_masked_mse: 5.5200e-04
# Epoch 26/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2714e-04 - masked_mse: 7.2714e-04 - val_loss: 5.9731e-04 - val_masked_mse: 6.1470e-04
# Epoch 27/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6122e-04 - masked_mse: 7.6122e-04 - val_loss: 5.3880e-04 - val_masked_mse: 5.7701e-04
# Epoch 28/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.3343e-04 - masked_mse: 7.3343e-04 - val_loss: 5.5664e-04 - val_masked_mse: 5.9246e-04
# Epoch 29/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.2197e-04 - masked_mse: 7.2197e-04 - val_loss: 6.5908e-04 - val_masked_mse: 6.8861e-04
# Epoch 30/30
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.2746e-04 - masked_mse: 7.2745e-04 - val_loss: 5.9706e-04 - val_masked_mse: 6.3342e-04
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9766e-04 - masked_mse: 1.9906e-04
# Test Loss: 0.000597057631239295, Test MAE: 0.000633419316727668
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
